# %%
from google.colab import auth
import pandas as pd

# get credentials
auth.authenticate_user()

query = '''
SELECT *
FROM `data-analytics-bootcamp-363212.neo_bank.devices`
'''
devices= pd.read_gbq(query, project_id="data-analytics-bootcamp-363212")
devices.head()
# Out:
#   string_field_0 string_field_1
# 0          Apple      user_6809
# 1          Apple      user_3636
# 2          Apple       user_510
# 3          Apple      user_3468
# 4          Apple      user_7036

# %%
devices.shape
# Out:
# (19431, 2)

# %%
query = '''
SELECT *
FROM `data-analytics-bootcamp-363212.neo_bank.notifications`
'''
notification= pd.read_gbq(query, project_id="data-analytics-bootcamp-363212")
notification
# Out:
#                                       reason channel  status     user_id  \
# 0                         METAL_RESERVE_PLAN     SMS    SENT   user_4703
# 1                         METAL_RESERVE_PLAN     SMS    SENT   user_2397
# 2                         METAL_RESERVE_PLAN     SMS    SENT   user_2411
# 3                         METAL_RESERVE_PLAN     SMS    SENT   user_1119
# 4                         METAL_RESERVE_PLAN     SMS    SENT   user_3499
# ...                                      ...     ...     ...         ...
# 121808  NO_INITIAL_FREE_PROMOPAGE_CARD_ORDER   EMAIL  FAILED  user_19156
# 121809  NO_INITIAL_FREE_PROMOPAGE_CARD_ORDER   EMAIL  FAILED  user_18016
# 121810  NO_INITIAL_FREE_PROMOPAGE_CARD_ORDER   EMAIL  FAILED  user_18016
# 121811  NO_INITIAL_FREE_PROMOPAGE_CARD_ORDER   EMAIL  FAILED  user_19023
# 121812  NO_INITIAL_FREE_PROMOPAGE_CARD_ORDER   EMAIL  FAILED  user_19156
#
#                            created_date
# 0      2018-10-14 01:48:13.319987+00:00
# ...

# %%
notification.shape
# Out:
# (121813, 5)

# %%
query = '''
SELECT *
FROM `data-analytics-bootcamp-363212.neo_bank.users`
'''
users= pd.read_gbq(query, project_id="data-analytics-bootcamp-363212")
users
# Out:
#           user_id  birth_year country                              city  \
# 0       user_2811        1988      IE                                 C
# 1       user_4750        1987      FR                                Ry
# 2      user_17686        1984      GB                               Ayr
# 3      user_18779        1965      GB                               Ayr
# 4       user_7823        1999      PL                               Buk
# ...           ...         ...     ...                               ...
# 19425  user_10774        1971      LT      Stupuru kaimas Joniskio raj.
# 19426  user_13408        1997      LT   Akademijos mstl., Kauno rajonas
# 19427   user_7913        1980      LT    Sangrūdos km., Kalvarijos sav.
# 19428   user_5542        1981      ES  San Isidro - Granadilla de Abona
# 19429  user_18093        1983      CZ    Dobrá Voda u Českých Budějovic
#
#                           created_date  user_settings_crypto_unlocked  \
# ...

# %%
users.shape
# Out:
# (19430, 12)

# %%
query = '''
SELECT *
FROM `data-analytics-bootcamp-363212.neo_bank.transactions`
'''
transactions= pd.read_gbq(query, project_id="data-analytics-bootcamp-363212")
transactions
# Out:
#               transaction_id transactions_type transactions_currency  \
# 0          transaction_17369          EXCHANGE                   AED
# 1           transaction_1539          EXCHANGE                   AED
# 2           transaction_1868          EXCHANGE                   AED
# 3           transaction_1948          EXCHANGE                   AED
# 4        transaction_1755821          EXCHANGE                   AED
# ...                      ...               ...                   ...
# 2740070  transaction_1846709      CARD_PAYMENT                   ZAR
# 2740071    transaction_89487      CARD_PAYMENT                   ZAR
# 2740072   transaction_227881      CARD_PAYMENT                   ZAR
# 2740073    transaction_88782      CARD_PAYMENT                   ZAR
# 2740074  transaction_1846020      CARD_PAYMENT                   ZAR
#
#          amount_usd transactions_state ea_cardholderpresence  ea_merchant_mcc  \
# ...

# %%
transactions.shape
# Out:
# (2740075, 12)

# %%
import pandas as pd

# %%
notification.to_csv('/content/drive/MyDrive/Colab Notebooks/Neo-bank-project/notification.csv')

# %%
users.to_csv('/content/drive/MyDrive/Colab_Notebooks/Neo-bank-project/users_v0.csv')

# %%
devices.to_csv('/content/drive/MyDrive/Colab Notebooks/Neo-bank-project/devices.csv')

# %%
transactions.to_csv('/content/drive/MyDrive/Colab Notebooks/Neo-bank-project/transactions.csv')
